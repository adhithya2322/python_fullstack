# %% [markdown]
# # Python Indentation

# %%
# Def: Indentation is used to define a block
#Unnecessary space is not allowed in a python
x = 10
y = 10.5
z = "Hello"
print(x, y, z)
# Out:
# 10 10.5 Hello

# %%
x = 10
if x ==10:
   print("Hello")
   print("World") # This statenebt is outside the if block
# Out:
# Hello
# World

# %%
#Interview Question
# python compiler differentiate btwn TAB & 4 Spaces
# It is not compulsory to give 4 soace ot tab soace for a block statements
# We can single, double, triple or any number of spaces

# %% [markdown]
# # Python Commments

# %%
# Singe line Comments
"""
comment
"""

'''
Multiline 
comment
'''
print("Hello World")
# Out:
# Hello World

# %%
# 1. # is used to define the comments in python
#2. Their is no multiline strings as  Multiline comments
# when we are not storing string into a variable

# %% [markdown]
# # Type Casting

# %%
# Integer typecasting : int()
v1 = int(5.0) # Float to Int
v2 = int("300") # String to int 
v3 = int(True) # Bool to int
v4 = int(False) # Bool to int
v5 = int("1010", 2)
print(v1, type(v1))
print(v2, type(v2))
print(v3, type(v3))
print(v4, type(v4))
print(v5, type(v5))
# Out:
# 5 <class 'int'>
# 300 <class 'int'>
# 1 <class 'int'>
# 0 <class 'int'>
# 10 <class 'int'>

# %%
#Convert to float: float()
v1 = float(10)
v2 = float("10.5")
v3 = float(True)
print(v1, type(v1))
print(v2, type(v2))
print(v3, type(v3))
# Out:
# 10.0 <class 'float'>
# 10.5 <class 'float'>
# 1.0 <class 'float'>

# %%
# COnvert to string: str()
v1 = str(200)
v2 = str(4.5)
v3 = str(True)
print(v1, type(v1))
print(v2, type(v2))
print(v3, type(v3))
# Out:
# 200 <class 'str'>
# 4.5 <class 'str'>
# True <class 'str'>

# %%
# Cpnvert to Boolean: bool()
v1 = bool(0)
v2 = bool(1)
v3 = bool(1548.201)
v4 = bool("Hello")
print(v1, type(v1))
print(v2, type(v2))
print(v3, type(v3))
print(v3, type(v))
# Out:
# False <class 'bool'>
# True <class 'bool'>
# True <class 'bool'>
