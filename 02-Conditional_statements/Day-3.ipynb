# %%
n = int(Input(Enter any number))

# %% [markdown]
# # 3. Assignment Operators(+=, -=, *=, /=, %=, )

# %%
a = 10
a+=5
print(a)

a-=5
print(a)

a*=5
print(a)

a/=5
print(int(a))

a%=5
print(a)

a-=5
print(a)
# Out:
# 15
# 10
# 50
# 10
# 0.0
# -5.0

# %%
a = 10
a &= 3
print(a)

a <= 3
print(a)

a >= 3
print(a)

a |= 3
print(a)

a << 3
print(a)

a >> 3
print(a)

a %= 3
print(a)0
# Out:
# 2
# 2
# 2
# 3
# 3
# 3

# %%
#Walrus Operator(:=)
# walrus operator will first assign the value to the variable then pass it to outer functiom

#x= 10
print(x := 2)
# Out:
# 2

# %% [markdown]
# # Comparison operators9 ==, >=, <=, !=, <, >)

# %%
a = 10
b = 5
print (a==b)

a = 10
b = 5
print (a>=b)

a = 10
b = 5
print (a<=b)

a = 10
b = 5
print (a!=b)


a = 10
b = 5
print (a !=b)
print (a < b)

a=10, 6
b=10, 7
print(a or b)
# Out:
# False
# True
# False
# True
# True
# False
# (10, 6)

# %% [markdown]
# # Logical operator

# %%
# and, or, not

a = True
b = False

print(a and b)
print(a or b)
print(not b)
# Out:
# False
# True
# True

# %% [markdown]
# # Identity Operator (is, is not)

# %%
a = [1,2,3]
b = [1,2,3]
c = a
print(a ==b)
print(a is b)

print(a is not b)
print(a is not c)
# Out:
# True
# False
# True
# False

# %% [markdown]
# # Membership operators

# %% [raw]
# # in, not In
# fruits = ["Mamidi", "Arati", "Bathai", "Panasa"]
# print("Bathai" in fruits)
#
# print("Bathai" not in fruits)

# %% [markdown]
# # Interview Questions from the Operators

# %%
a = 10
b = 20

# %%
p1 = 1000000
p2 = 1000000
p3 = 1000000
print(p1 ^ p2 ^ p3)
# Out:
# 1000000

# %%
a = 11
if(a & 1):
    print("ODD")
else:
    print("EVEN")
# Out:
# ODD
