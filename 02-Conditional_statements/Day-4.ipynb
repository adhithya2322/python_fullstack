# %% [markdown]
# # Input in python

# %%
val =input("Enter Your Name:")
print(val)
print(type(val))
# Out:
# Enter Your Name: adhithya
# adhithya
# <class 'str'>

# %%
val = float(input("Enter Phone Number:"))
print(val)
print(type(val))
# Out:
# Enter Phone Number: 7993630968
# 7993630968.0
# <class 'float'>

# %%
# Recieving multiple inputs \ using split()
v1, v2, v3 = map(int, input("Enter 3 Numbers").split(','))
print(v1, v2, v3)
# Out:
# Enter 3 Numbers 100,200,300
# 100 200 300

# %%
x= list(map(int, input("Enter any Number of Values:").split(',')))
print(x)
# Out:
# Enter any Number of Values: 1,2,4,5,7
# [1, 2, 4, 5, 7]

# %% [markdown]
# # Output in python

# %%
# 1. Concatenation using Cammas
# 2. String concatenation using +
# 3. str.format()
# 4. f. string method()
# 5. Escpae Sequences
# 6. End and separate parameters in print()

# %%
# 1. Concatenation using Cammas

Hero_name = 'Prabhas'
age = 60
Fee = 100000
print(Hero_name, age, Fee)
# Out:
# Prabhas 60 100000

# %%
# 2. String concatenation using +
Hero_name = 'prabhas'
Heroine_name = 'Anushka'

fee = 100000
print(Hero_name + " "+ Heroine_name + " "+ str(fee)
     )
# Out:
# prabhas Anushka 100000

# %%
# 3. str.format()
Hero_name = 'prabhas'
age = 60
print("Name: {} Age: {}".format(Hero_name,age))
# Out:
# Name: prabhas Age: 60

# %%
# 4. f. string method()

Hero_name="NTR"
age=10
fee=100
print(f"Name: \"{Hero_name}\" \n Age: {age} \n fee: {fee}")
# Out:
# Name: "NTR"
#  Age: 10
#  fee: 100

# %%
Hero_name="NTR"
age=10
fee=100
print(f"Name: \"{Hero_name}\" \t Age: {age} \t fee: {fee}")
# Out:
# Name: "NTR" 	 Age: 10 	 fee: 100

# %%
# 6. End and separate parameters in print()


Hero_name="Prabhas"
Heroine_name = 'Anushka'

age=10
fee=100

print(Hero_name, end = " \n")
print(Heroine_name)
# Out:
# Prabhas
# Anushka

# %%
print(Hero_name,Heroine_name,fee, sep="@")
# Out:
# Prabhas@Anushka@100

# %%
#end parameter is used to decide how the print statement will END:
#sep parameter decides how the multiplr values will be separeted
